# %%
# JDME Series de tiempo
import statsmodels.api as sm 
import matplotlib.pyplot as plt

# %%
dta = sm.datasets.co2.load_pandas().data

# %%
dta.plot()
plt.title('Niveles de CO2')
plt.ylabel('Partes por millón')
plt.xlabel('Año')
plt.show()
dta
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4
# ...           ...
# 2001-12-01  370.3
# 2001-12-08  370.8
# 2001-12-15  371.2
# 2001-12-22  371.3
# 2001-12-29  371.5
#
# [2284 rows x 1 columns]

# %%
import yfinance as yf
import numpy as np

# %%
ticker_google = 'GOOGL'
start_date = '2018-01-01'
end_date = '2025-12-31'
df_google =yf.download(ticker_google, start=start_date, end=end_date)
# Out:
# C:\Users\Juan Diego\AppData\Local\Temp\ipykernel_9636\1873559084.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_google =yf.download(ticker_google, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
df_google
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2018-01-02   53.292931   53.430482   52.290347   52.290347  31766000
# 2018-01-03   54.202168   54.429599   53.303864   53.328691  31318000
# 2018-01-04   54.412708   54.825859   54.338225   54.478754  26052000
# 2018-01-05   55.134235   55.297610   54.712644   54.794579  30250000
# 2018-01-08   55.328892   55.574698   55.119835   55.169492  24644000
# ...                ...         ...         ...         ...       ...
# 2025-11-03  283.720001  285.529999  279.799988  282.179993  29786000
# 2025-11-04  277.540009  281.269989  276.260010  276.750000  30078400
# 2025-11-05  284.309998  286.420013  277.339996  278.869995  31010300
# 2025-11-06  284.750000  288.350006  281.140015  285.329987  37173600
# 2025-11-07  278.829987  283.779999  275.190002  283.130005  34104158
#
# [1975 rows x 5 columns]

# %%
df_google['Close'].plot()
plt.title('Eje Normal')
plt.show()

# %%
df_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1975 entries, 2018-01-02 to 2025-11-07
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Close, GOOGL)   1975 non-null   float64
#  1   (High, GOOGL)    1975 non-null   float64
#  2   (Low, GOOGL)     1975 non-null   float64
#  3   (Open, GOOGL)    1975 non-null   float64
#  4   (Volume, GOOGL)  1975 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 92.6 KB

# %%
df_google['LogClose'] = np.log(df_google['Close'])

# %%
df_google
# Out:
# Price            Close        High         Low        Open    Volume  LogClose
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2018-01-02   53.292931   53.430482   52.290347   52.290347  31766000  3.975804
# 2018-01-03   54.202168   54.429599   53.303864   53.328691  31318000  3.992721
# 2018-01-04   54.412708   54.825859   54.338225   54.478754  26052000  3.996598
# 2018-01-05   55.134235   55.297610   54.712644   54.794579  30250000  4.009771
# 2018-01-08   55.328892   55.574698   55.119835   55.169492  24644000  4.013295
# ...                ...         ...         ...         ...       ...       ...
# 2025-11-03  283.720001  285.529999  279.799988  282.179993  29786000  5.647988
# 2025-11-04  277.540009  281.269989  276.260010  276.750000  30078400  5.625965
# 2025-11-05  284.309998  286.420013  277.339996  278.869995  31010300  5.650065
# 2025-11-06  284.750000  288.350006  281.140015  285.329987  37173600  5.651612
# 2025-11-07  278.829987  283.779999  275.190002  283.130005  34104158  5.630602
#
# [1975 rows x 6 columns]

# %%
df_google['LogClose'].plot()
plt.title('Ejer logaritmico')
plt.show()
